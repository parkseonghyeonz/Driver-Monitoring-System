# %%
from ultralytics import YOLO

model = YOLO(r"C:\DMS\model\yolo12l.pt")

img_path = r"C:\DMS\usephonedataset"

results = model(img_path, save=True)  

results[0].show()
# Out:
# image 1/3 C:\DMS\usephonedataset\usephoneimg1.jpg: 448x640 1 person, 1 cell phone, 57.6ms
# image 2/3 C:\DMS\usephonedataset\usephoneimg2.jpg: 448x640 1 person, 1 car, 1 cell phone, 46.2ms
# image 3/3 C:\DMS\usephonedataset\usephoneimg3.jpg: 448x640 1 person, 1 cell phone, 44.5ms
# Speed: 5.1ms preprocess, 49.5ms inference, 2.8ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to C:\DMS\runs\detect\predict4

# %%
from ultralytics import YOLO

model = YOLO("yolo12-pose.pt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 from ultralytics import YOLO
# ----> 3 model = YOLO("yolo12-pose.pt")
#
# File c:\Users\sungh\miniconda3\envs\dms\Lib\site-packages\ultralytics\models\yolo\model.py:81, in YOLO.__init__(self, model, task, verbose)
#      78     self.__dict__ = new_instance.__dict__
#      79 else:
#      80     # Continue with default YOLO initialization
# ---> 81     super().__init__(model=model, task=task, verbose=verbose)
#      82     if hasattr(self.model, "model") and "RTDETR" in self.model.model[-1]._get_name():  # if RTDETR head
#      83         from ultralytics import RTDETR
#
# File c:\Users\sungh\miniconda3\envs\dms\Lib\site-packages\ultralytics\engine\model.py:149, in Model.__init__(self, model, task, verbose)
#     147     self._new(model, task=task, verbose=verbose)
#     148 else:
# ...

# %%
!pip install ultralytics

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo12s-pose.pt")  # load a pretrained model (recommended for training)

# Train the model
results = model.train(data="hand-keypoints.yaml", epochs=100, imgsz=640)

# %%
from ultralytics import YOLO

model = YOLO(r'C:\DMS\model\helmet_best.pt')

metrics = model.val(data='/Users/bagseonghyeon/Desktop/haring/AI/yolo/data.yaml')  

# print(metrics)

print(f"Precision: {metrics.box.map50:.4f}")  
print(f"Recall: {metrics.box.map50:.4f}")     
print(f"F1-score: {metrics.box.map:.4f}") 
print(f"Accuracy: {metrics.box.map50:.4f}")
